# %%
import IPython.display as ipd
import numpy as np
import pandas as pd

import librosa
import matplotlib.pyplot as plt
from scipy.io import wavfile as wav

from sklearn import metrics 
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split 

from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import Adam
from keras.utils import to_categorical

# %%
feature = pd.read_csv("./urbansound8k_features.csv")
print(feature["MFCC_1_mean"])
feature = np.array(feature)
x = feature[:,15:-1]
x = np.asarray(x).astype(np.float64)
print(x)
y = feature[:,-1]
print(y)
# Out:
# 0      -209.93578
# 1      -417.29105
# 2      -452.77457
# 3      -406.86542
# 4      -440.05148
#           ...
# 8727   -391.71950
# 8728   -339.43976
# 8729   -297.74582
# 8730   -337.20972
# 8731   -307.73666
# Name: MFCC_1_mean, Length: 8732, dtype: float64
# [[-2.09935780e+02 -2.09935780e+02  6.34226300e+01 ... -1.89823080e+00
#    1.35495270e+00  1.35495270e+00]
#  [-4.17291050e+02 -4.17291050e+02  1.00148506e+02 ... -2.07825570e+00
#    1.98517660e+00  1.98517660e+00]
#  [-4.52774570e+02 -4.52774570e+02  1.13243030e+02 ... -3.79127120e-01
#    1.09250390e+00  1.09250390e+00]
#  ...
#  [-2.97745820e+02 -2.97745820e+02  1.02953360e+02 ...  9.65810840e-01
#    9.41966150e+00  9.41966150e+00]
#  [-3.37209720e+02 -3.37209720e+02  1.16191270e+02 ... -3.16817700e+00
#    7.24798970e+00  7.24798970e+00]
#  [-3.07736660e+02 -3.07736660e+02  8.41291700e+01 ... -1.20706630e+01
#   -5.32664500e+00 -5.32664500e+00]]
# [3 2 2 ... 1 1 1]

# %%
# split the dataset
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
le = LabelEncoder()
y = to_categorical(le.fit_transform(y))
print(y.shape)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state = 127)

num_labels = y.shape[1]
feature_length = x.shape[1]
filter_size = 2
def build_model_graph(input_shape=(52,)):
    model = Sequential()
    model.add(Dense(256))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(256))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    model.add(Dense(10))
    model.add(Activation('softmax'))
    # Compile the model
    model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

    return model
model = build_model_graph()

num_epochs = 100
num_batch_size = 32

model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(x_test, y_test), verbose=1)

score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: {0:.2%}".format(score[1]))

score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: {0:.2%}".format(score[1]))
# Out:
# (8732, 10)
# Epoch 1/100
# 219/219 [==============================] - 0s 2ms/step - loss: 10.0861 - accuracy: 0.2097 - val_loss: 2.0672 - val_accuracy: 0.3160
# Epoch 2/100
# 219/219 [==============================] - 0s 1ms/step - loss: 2.2346 - accuracy: 0.2836 - val_loss: 1.9139 - val_accuracy: 0.3967
# Epoch 3/100
# 219/219 [==============================] - 0s 1ms/step - loss: 1.9195 - accuracy: 0.3479 - val_loss: 1.6425 - val_accuracy: 0.4883
# Epoch 4/100
# 219/219 [==============================] - 0s 1ms/step - loss: 1.6858 - accuracy: 0.4206 - val_loss: 1.4333 - val_accuracy: 0.5478
# Epoch 5/100
# 219/219 [==============================] - 0s 1ms/step - loss: 1.5490 - accuracy: 0.4697 - val_loss: 1.3355 - val_accuracy: 0.6010
# Epoch 6/100
# 219/219 [==============================] - 0s 1ms/step - loss: 1.4145 - accuracy: 0.5165 - val_loss: 1.2483 - val_accuracy: 0.6371
# Epoch 7/100
# 219/219 [==============================] - 0s 1ms/step - loss: 1.3347 - accuracy: 0.5492 - val_loss: 1.1603 - val_accuracy: 0.6434
# Epoch 8/100
# 219/219 [==============================] - 0s 1ms/step - loss: 1.2761 - accuracy: 0.5699 - val_loss: 1.0772 - val_accuracy: 0.6617
# Epoch 9/100
# 219/219 [==============================] - 0s 1ms/step - loss: 1.2261 - accuracy: 0.5874 - val_loss: 1.0425 - val_accuracy: 0.6846
# Epoch 10/100
# 219/219 [==============================] - 0s 1ms/step - loss: 1.1684 - accuracy: 0.6040 - val_loss: 0.9815 - val_accuracy: 0.6920
# Epoch 11/100
# 219/219 [==============================] - 0s 1ms/step - loss: 1.1156 - accuracy: 0.6220 - val_loss: 0.9635 - val_accuracy: 0.7081
# Epoch 12/100
# 219/219 [==============================] - 0s 1ms/step - loss: 1.1125 - accuracy: 0.6271 - val_loss: 0.9453 - val_accuracy: 0.7172
# Epoch 13/100
# 219/219 [==============================] - 0s 1ms/step - loss: 1.0589 - accuracy: 0.6431 - val_loss: 0.9104 - val_accuracy: 0.7241
# Epoch 14/100
# 219/219 [==============================] - 0s 1ms/step - loss: 1.0235 - accuracy: 0.6543 - val_loss: 0.8596 - val_accuracy: 0.7367
# Epoch 15/100
# 219/219 [==============================] - 0s 1ms/step - loss: 1.0089 - accuracy: 0.6624 - val_loss: 0.8275 - val_accuracy: 0.7579
# Epoch 16/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.9810 - accuracy: 0.6666 - val_loss: 0.7873 - val_accuracy: 0.7659
# Epoch 17/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.9454 - accuracy: 0.6809 - val_loss: 0.8101 - val_accuracy: 0.7590
# Epoch 18/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.9544 - accuracy: 0.6786 - val_loss: 0.8194 - val_accuracy: 0.7516
# Epoch 19/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.9168 - accuracy: 0.6879 - val_loss: 0.7397 - val_accuracy: 0.7825
# Epoch 20/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.8874 - accuracy: 0.6978 - val_loss: 0.7282 - val_accuracy: 0.7888
# Epoch 21/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.8697 - accuracy: 0.7079 - val_loss: 0.6992 - val_accuracy: 0.7951
# Epoch 22/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.8611 - accuracy: 0.7125 - val_loss: 0.7253 - val_accuracy: 0.7888
# Epoch 23/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.8600 - accuracy: 0.7104 - val_loss: 0.6982 - val_accuracy: 0.7836
# Epoch 24/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.8450 - accuracy: 0.7132 - val_loss: 0.6916 - val_accuracy: 0.7922
# Epoch 25/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.8082 - accuracy: 0.7264 - val_loss: 0.6870 - val_accuracy: 0.7951
# Epoch 26/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.8091 - accuracy: 0.7306 - val_loss: 0.6306 - val_accuracy: 0.8163
# Epoch 27/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.8129 - accuracy: 0.7225 - val_loss: 0.6511 - val_accuracy: 0.8082
# Epoch 28/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.7927 - accuracy: 0.7370 - val_loss: 0.6587 - val_accuracy: 0.7979
# Epoch 29/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.7694 - accuracy: 0.7419 - val_loss: 0.6525 - val_accuracy: 0.7997
# Epoch 30/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.7813 - accuracy: 0.7350 - val_loss: 0.6420 - val_accuracy: 0.7968
# Epoch 31/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.7404 - accuracy: 0.7549 - val_loss: 0.5921 - val_accuracy: 0.8203
# Epoch 32/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.7448 - accuracy: 0.7462 - val_loss: 0.6194 - val_accuracy: 0.8191
# Epoch 33/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.7345 - accuracy: 0.7500 - val_loss: 0.5786 - val_accuracy: 0.8214
# Epoch 34/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.7531 - accuracy: 0.7477 - val_loss: 0.6299 - val_accuracy: 0.8088
# Epoch 35/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.7580 - accuracy: 0.7407 - val_loss: 0.5755 - val_accuracy: 0.8334
# Epoch 36/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.7308 - accuracy: 0.7555 - val_loss: 0.5868 - val_accuracy: 0.8157
# Epoch 37/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.7138 - accuracy: 0.7599 - val_loss: 0.5802 - val_accuracy: 0.8231
# Epoch 38/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.7072 - accuracy: 0.7613 - val_loss: 0.5999 - val_accuracy: 0.8197
# Epoch 39/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.7149 - accuracy: 0.7573 - val_loss: 0.5688 - val_accuracy: 0.8306
# Epoch 40/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.7046 - accuracy: 0.7586 - val_loss: 0.5881 - val_accuracy: 0.8311
# Epoch 41/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.6886 - accuracy: 0.7668 - val_loss: 0.5557 - val_accuracy: 0.8351
# Epoch 42/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.7130 - accuracy: 0.7601 - val_loss: 0.5470 - val_accuracy: 0.8340
# Epoch 43/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.6998 - accuracy: 0.7675 - val_loss: 0.5478 - val_accuracy: 0.8323
# Epoch 44/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.6574 - accuracy: 0.7780 - val_loss: 0.5637 - val_accuracy: 0.8163
# Epoch 45/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.6863 - accuracy: 0.7708 - val_loss: 0.5426 - val_accuracy: 0.8311
# Epoch 46/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.6666 - accuracy: 0.7737 - val_loss: 0.5373 - val_accuracy: 0.8426
# Epoch 47/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.6795 - accuracy: 0.7678 - val_loss: 0.5247 - val_accuracy: 0.8472
# Epoch 48/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.6521 - accuracy: 0.7811 - val_loss: 0.5530 - val_accuracy: 0.8300
# Epoch 49/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.6672 - accuracy: 0.7824 - val_loss: 0.5376 - val_accuracy: 0.8329
# Epoch 50/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.6548 - accuracy: 0.7767 - val_loss: 0.5336 - val_accuracy: 0.8306
# Epoch 51/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.6794 - accuracy: 0.7732 - val_loss: 0.5281 - val_accuracy: 0.8414
# Epoch 52/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.6411 - accuracy: 0.7835 - val_loss: 0.5215 - val_accuracy: 0.8420
# Epoch 53/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.6520 - accuracy: 0.7817 - val_loss: 0.5187 - val_accuracy: 0.8506
# Epoch 54/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.6520 - accuracy: 0.7828 - val_loss: 0.5312 - val_accuracy: 0.8334
# Epoch 55/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.6597 - accuracy: 0.7828 - val_loss: 0.5360 - val_accuracy: 0.8483
# Epoch 56/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.6389 - accuracy: 0.7854 - val_loss: 0.5125 - val_accuracy: 0.8432
# Epoch 57/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.6396 - accuracy: 0.7890 - val_loss: 0.5348 - val_accuracy: 0.8208
# Epoch 58/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.6218 - accuracy: 0.7904 - val_loss: 0.5162 - val_accuracy: 0.8500
# Epoch 59/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.6150 - accuracy: 0.7933 - val_loss: 0.5302 - val_accuracy: 0.8363
# Epoch 60/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.6207 - accuracy: 0.7920 - val_loss: 0.5099 - val_accuracy: 0.8500
# Epoch 61/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.6358 - accuracy: 0.7933 - val_loss: 0.5261 - val_accuracy: 0.8346
# Epoch 62/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.6090 - accuracy: 0.7930 - val_loss: 0.5102 - val_accuracy: 0.8432
# Epoch 63/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.6545 - accuracy: 0.7917 - val_loss: 0.5364 - val_accuracy: 0.8351
# Epoch 64/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.6171 - accuracy: 0.7979 - val_loss: 0.5113 - val_accuracy: 0.8517
# Epoch 65/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.6079 - accuracy: 0.7931 - val_loss: 0.5229 - val_accuracy: 0.8449
# Epoch 66/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.6037 - accuracy: 0.7997 - val_loss: 0.5264 - val_accuracy: 0.8380
# Epoch 67/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.5961 - accuracy: 0.7986 - val_loss: 0.5006 - val_accuracy: 0.8586
# Epoch 68/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.5858 - accuracy: 0.8021 - val_loss: 0.4971 - val_accuracy: 0.8477
# Epoch 69/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.5972 - accuracy: 0.8013 - val_loss: 0.4912 - val_accuracy: 0.8506
# Epoch 70/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.6353 - accuracy: 0.7861 - val_loss: 0.5152 - val_accuracy: 0.8443
# Epoch 71/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.5981 - accuracy: 0.7980 - val_loss: 0.5161 - val_accuracy: 0.8580
# Epoch 72/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.6097 - accuracy: 0.7943 - val_loss: 0.5179 - val_accuracy: 0.8523
# Epoch 73/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.5941 - accuracy: 0.8039 - val_loss: 0.4992 - val_accuracy: 0.8460
# Epoch 74/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.5907 - accuracy: 0.8010 - val_loss: 0.4885 - val_accuracy: 0.8460
# Epoch 75/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.6101 - accuracy: 0.7951 - val_loss: 0.4877 - val_accuracy: 0.8552
# Epoch 76/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.6005 - accuracy: 0.8007 - val_loss: 0.4891 - val_accuracy: 0.8546
# Epoch 77/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.6013 - accuracy: 0.7984 - val_loss: 0.4952 - val_accuracy: 0.8563
# Epoch 78/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.5886 - accuracy: 0.8031 - val_loss: 0.4959 - val_accuracy: 0.8500
# Epoch 79/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.5931 - accuracy: 0.7983 - val_loss: 0.5139 - val_accuracy: 0.8495
# Epoch 80/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.5764 - accuracy: 0.8105 - val_loss: 0.4944 - val_accuracy: 0.8535
# Epoch 81/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.6105 - accuracy: 0.7979 - val_loss: 0.5077 - val_accuracy: 0.8512
# Epoch 82/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.5973 - accuracy: 0.8029 - val_loss: 0.4898 - val_accuracy: 0.8586
# Epoch 83/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.6017 - accuracy: 0.7997 - val_loss: 0.4724 - val_accuracy: 0.8695
# Epoch 84/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.5875 - accuracy: 0.8027 - val_loss: 0.4749 - val_accuracy: 0.8575
# Epoch 85/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.5712 - accuracy: 0.8084 - val_loss: 0.4645 - val_accuracy: 0.8672
# Epoch 86/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.5723 - accuracy: 0.8106 - val_loss: 0.4815 - val_accuracy: 0.8586
# Epoch 87/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.5583 - accuracy: 0.8147 - val_loss: 0.4749 - val_accuracy: 0.8620
# Epoch 88/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.5948 - accuracy: 0.8047 - val_loss: 0.4949 - val_accuracy: 0.8586
# Epoch 89/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.5923 - accuracy: 0.8059 - val_loss: 0.4911 - val_accuracy: 0.8546
# Epoch 90/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.5632 - accuracy: 0.8120 - val_loss: 0.4664 - val_accuracy: 0.8729
# Epoch 91/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.5657 - accuracy: 0.8079 - val_loss: 0.4853 - val_accuracy: 0.8500
# Epoch 92/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.5544 - accuracy: 0.8135 - val_loss: 0.4685 - val_accuracy: 0.8615
# Epoch 93/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.5643 - accuracy: 0.8136 - val_loss: 0.4552 - val_accuracy: 0.8741
# Epoch 94/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.5464 - accuracy: 0.8162 - val_loss: 0.4695 - val_accuracy: 0.8620
# Epoch 95/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.5473 - accuracy: 0.8199 - val_loss: 0.4778 - val_accuracy: 0.8626
# Epoch 96/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.5705 - accuracy: 0.8064 - val_loss: 0.4747 - val_accuracy: 0.8695
# Epoch 97/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.5773 - accuracy: 0.8119 - val_loss: 0.4753 - val_accuracy: 0.8695
# Epoch 98/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.5326 - accuracy: 0.8175 - val_loss: 0.4582 - val_accuracy: 0.8752
# Epoch 99/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.5810 - accuracy: 0.8070 - val_loss: 0.4762 - val_accuracy: 0.8592
# Epoch 100/100
# 219/219 [==============================] - 0s 1ms/step - loss: 0.5844 - accuracy: 0.8056 - val_loss: 0.4668 - val_accuracy: 0.8626
# Training Accuracy: 91.50%
# Testing Accuracy: 86.26%

# %%
# Load various imports 
import pandas as pd
import os
import librosa
import librosa.display

import struct

class WavFileHelper():
    
    def read_file_properties(self, filename):

        wave_file = open(filename,"rb")
        
        riff = wave_file.read(12)
        fmt = wave_file.read(36)
        
        num_channels_string = fmt[10:12]
        num_channels = struct.unpack('<H', num_channels_string)[0]

        sample_rate_string = fmt[12:16]
        sample_rate = struct.unpack("<I",sample_rate_string)[0]
        
        bit_depth_string = fmt[22:24]
        bit_depth = struct.unpack("<H",bit_depth_string)[0]

        return (num_channels, sample_rate, bit_depth)

wavfilehelper = WavFileHelper()

metadata = pd.read_csv('UrbanSound8K.csv')

audiodata = []
for index, row in metadata.iterrows():
    
    file_name = os.path.join(os.path.abspath('./urbansound8K/'),'fold'+str(row["fold"])+'/',str(row["slice_file_name"]))
    data = wavfilehelper.read_file_properties(file_name)
    audiodata.append(data)

# Convert into a Panda dataframe
audiodf = pd.DataFrame(audiodata, columns=['num_channels','sample_rate','bit_depth'])

# %%
def extract_features(file_name):
   
    try:
        audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
        mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
        mfccsscaled = np.mean(mfccs.T,axis=1)
        print(mfccsscaled.shape)
    except Exception as e:
        print("Error encountered while parsing file: ", file)
        return None 
     
    return mfccsscaled
    
    
# Load various imports 
import pandas as pd
import os
import librosa

# Set the path to the full UrbanSound dataset 
fulldatasetpath = './UrbanSound8K/'

features = []

# Iterate through each sound file and extract the features 
for index, row in metadata.iterrows():
    
    file_name = os.path.join(os.path.abspath(fulldatasetpath),'fold'+str(row["fold"])+'/',str(row["slice_file_name"]))
    
    class_label = row["class"]
    data = extract_features(file_name)
    
    features.append([data, class_label])

# Convert into a Panda dataframe 
featuresdf = pd.DataFrame(features, columns=['feature','class_label'])

print('Finished feature extraction from ', len(featuresdf), ' files')
# Out:
# (14,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (28,)
# (46,)
# (18,)
# (70,)
# (81,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (134,)
# (23,)
# (17,)
# (35,)
# (173,)
# (71,)
# (113,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (60,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (109,)
# (42,)
# (20,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (66,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (109,)
# (58,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (50,)
# (26,)
# (36,)
# (35,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (76,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (32,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (22,)
# (47,)
# (60,)
# (74,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (102,)
# (173,)
# (173,)
# (49,)
# (173,)
# (173,)
# (173,)
# (24,)
# (173,)
# (173,)
# (173,)
# (173,)
# (65,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (57,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (35,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (110,)
# (173,)
# (173,)
# (173,)
# (141,)
# (173,)
# (45,)
# (41,)
# (140,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (19,)
# (26,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (44,)
# (156,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (22,)
# (128,)
# (30,)
# (12,)
# (18,)
# (49,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (55,)
# (19,)
# (173,)
# (173,)
# (173,)
# (173,)
# (25,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (10,)
# (46,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (27,)
# (36,)
# (34,)
# (41,)
# (42,)
# (36,)
# (36,)
# (18,)
# (21,)
# (11,)
# (9,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (115,)
# (34,)
# (92,)
# (23,)
# (48,)
# (173,)
# (173,)
# (173,)
# (129,)
# (79,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (28,)
# (173,)
# (173,)
# (33,)
# (173,)
# (173,)
# (173,)
# (173,)
# (136,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (38,)
# (94,)
# (38,)
# (38,)
# (25,)
# (173,)
# (173,)
# (173,)
# (72,)
# (63,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (32,)
# (52,)
# (52,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (108,)
# (88,)
# (30,)
# (25,)
# (23,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (112,)
# (132,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (13,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (82,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (172,)
# (63,)
# (50,)
# (16,)
# (86,)
# (34,)
# (59,)
# (16,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (61,)
# (84,)
# (77,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (64,)
# (63,)
# (113,)
# (103,)
# (116,)
# (24,)
# (112,)
# (66,)
# (78,)
# (99,)
# (95,)
# (89,)
# (81,)
# (86,)
# (56,)
# (140,)
# (37,)
# (82,)
# (84,)
# (74,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (92,)
# (56,)
# (95,)
# (98,)
# (106,)
# (103,)
# (79,)
# (90,)
# (106,)
# (94,)
# (92,)
# (80,)
# (101,)
# (173,)
# (123,)
# (173,)
# (173,)
# (173,)
# (97,)
# (87,)
# (70,)
# (56,)
# (53,)
# (101,)
# (103,)
# (41,)
# (22,)
# (46,)
# (50,)
# (43,)
# (53,)
# (63,)
# (70,)
# (79,)
# (74,)
# (77,)
# (65,)
# (53,)
# (72,)
# (65,)
# (58,)
# (29,)
# (63,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (40,)
# (145,)
# (159,)
# (140,)
# (127,)
# (85,)
# (102,)
# (84,)
# (113,)
# (67,)
# (88,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (162,)
# (156,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (135,)
# (129,)
# (57,)
# (53,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (50,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (92,)
# (132,)
# (123,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (17,)
# (26,)
# (52,)
# (52,)
# (20,)
# (16,)
# (173,)
# (173,)
# (173,)
# (173,)
# (102,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (78,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (120,)
# (168,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (93,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (12,)
# (54,)
# (64,)
# (41,)
# (53,)
# (42,)
# (33,)
# (37,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (48,)
# (44,)
# (45,)
# (42,)
# (40,)
# (55,)
# (47,)
# (50,)
# (51,)
# (48,)
# (49,)
# (46,)
# (42,)
# (35,)
# (40,)
# (49,)
# (53,)
# (60,)
# (40,)
# (43,)
# (43,)
# (22,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (89,)
# (48,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (169,)
# (56,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (16,)
# (20,)
# (17,)
# (55,)
# (74,)
# (50,)
# (47,)
# (61,)
# (91,)
# (96,)
# (87,)
# (74,)
# (168,)
# (74,)
# (133,)
# (28,)
# (48,)
# (173,)
# (173,)
# (173,)
# (45,)
# (173,)
# (52,)
# (30,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (44,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (41,)
# (34,)
# (34,)
# (44,)
# (24,)
# (50,)
# (47,)
# (64,)
# (81,)
# (29,)
# (36,)
# (41,)
# (55,)
# (65,)
# (31,)
# (53,)
# (52,)
# (63,)
# (44,)
# (52,)
# (52,)
# (66,)
# (58,)
# (72,)
# (36,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (22,)
# (20,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (69,)
# (80,)
# (75,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (7,)
# (7,)
# (5,)
# (5,)
# (61,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (105,)
# (173,)
# (97,)
# (121,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (48,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (5,)
# (7,)
# (95,)
# (8,)
# (30,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (91,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (27,)
# (28,)
# (116,)
# (173,)
# (173,)
# (173,)
# (173,)
# (53,)
# (120,)
# (159,)
# (173,)
# (34,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (50,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (76,)
# (11,)
# (106,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (86,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (44,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (33,)
# (40,)
# (26,)
# (26,)
# (26,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (55,)
# (53,)
# (25,)
# (122,)
# (49,)
# (66,)
# (46,)
# (76,)
# (56,)
# (111,)
# (46,)
# (51,)
# (149,)
# (127,)
# (138,)
# (85,)
# (51,)
# (39,)
# (41,)
# (90,)
# (55,)
# (44,)
# (45,)
# (90,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (98,)
# (50,)
# (109,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (61,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (44,)
# (103,)
# (88,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (82,)
# (75,)
# (102,)
# (51,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (82,)
# (88,)
# (68,)
# (76,)
# (100,)
# (106,)
# (87,)
# (26,)
# (25,)
# (26,)
# (28,)
# (26,)
# (27,)
# (90,)
# (81,)
# (85,)
# (57,)
# (71,)
# (92,)
# (15,)
# (13,)
# (13,)
# (13,)
# (13,)
# (14,)
# (28,)
# (83,)
# (51,)
# (47,)
# (81,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (61,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (71,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (42,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (47,)
# (30,)
# (25,)
# (130,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (6,)
# (6,)
# (9,)
# (173,)
# (173,)
# (173,)
# (173,)
# (45,)
# (46,)
# (59,)
# (57,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (76,)
# (57,)
# (32,)
# (102,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (35,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (146,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (161,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (109,)
# (86,)
# (78,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (20,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (47,)
# (48,)
# (28,)
# (37,)
# (46,)
# (47,)
# (43,)
# (42,)
# (44,)
# (36,)
# (25,)
# (47,)
# (50,)
# (45,)
# (47,)
# (52,)
# (50,)
# (47,)
# (59,)
# (28,)
# (22,)
# (19,)
# (20,)
# (24,)
# (22,)
# (23,)
# (19,)
# (19,)
# (36,)
# (32,)
# (36,)
# (31,)
# (31,)
# (25,)
# (32,)
# (78,)
# (16,)
# (14,)
# (21,)
# (21,)
# (20,)
# (19,)
# (5,)
# (37,)
# (50,)
# (19,)
# (34,)
# (29,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (152,)
# (149,)
# (86,)
# (73,)
# (74,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (21,)
# (34,)
# (65,)
# (34,)
# (33,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (169,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (129,)
# (173,)
# (173,)
# (169,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (169,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (115,)
# (81,)
# (83,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (30,)
# (38,)
# (41,)
# (38,)
# (38,)
# (44,)
# (47,)
# (68,)
# (69,)
# (71,)
# (50,)
# (55,)
# (43,)
# (61,)
# (62,)
# (24,)
# (17,)
# (53,)
# (47,)
# (47,)
# (45,)
# (56,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (90,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (139,)
# (11,)
# (63,)
# (10,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (58,)
# (48,)
# (71,)
# (102,)
# (107,)
# (50,)
# (55,)
# (173,)
# (58,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (88,)
# (173,)
# (173,)
# (173,)
# (128,)
# (130,)
# (173,)
# (105,)
# (93,)
# (131,)
# (173,)
# (173,)
# (173,)
# (127,)
# (86,)
# (108,)
# (173,)
# (68,)
# (56,)
# (89,)
# (68,)
# (79,)
# (63,)
# (76,)
# (156,)
# (86,)
# (82,)
# (97,)
# (79,)
# (98,)
# (98,)
# (67,)
# (86,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (72,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (26,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (5,)
# (103,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (38,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (11,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (33,)
# (25,)
# (13,)
# (117,)
# (96,)
# (59,)
# (42,)
# (146,)
# (55,)
# (42,)
# (121,)
# (46,)
# (50,)
# (134,)
# (67,)
# (173,)
# (38,)
# (30,)
# (154,)
# (67,)
# (173,)
# (100,)
# (109,)
# (113,)
# (96,)
# (104,)
# (46,)
# (71,)
# (167,)
# (25,)
# (173,)
# (173,)
# (173,)
# (55,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (74,)
# (173,)
# (61,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (3,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (102,)
# (106,)
# (173,)
# (173,)
# (173,)
# (124,)
# (131,)
# (112,)
# (113,)
# (164,)
# (110,)
# (114,)
# (130,)
# (111,)
# (114,)
# (161,)
# (78,)
# (97,)
# (85,)
# (80,)
# (96,)
# (102,)
# (106,)
# (97,)
# (91,)
# (109,)
# (100,)
# (104,)
# (127,)
# (125,)
# (151,)
# (106,)
# (101,)
# (103,)
# (110,)
# (137,)
# (133,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (129,)
# (78,)
# (28,)
# (56,)
# (41,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (21,)
# (39,)
# (39,)
# (32,)
# (65,)
# (36,)
# (24,)
# (23,)
# (75,)
# (63,)
# (49,)
# (13,)
# (30,)
# (24,)
# (12,)
# (13,)
# (49,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (49,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (86,)
# (12,)
# (24,)
# (35,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (17,)
# (27,)
# (20,)
# (32,)
# (33,)
# (48,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (158,)
# (126,)
# (44,)
# (78,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (89,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (46,)
# (84,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (69,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (15,)
# (47,)
# (23,)
# (17,)
# (33,)
# (35,)
# (58,)
# (21,)
# (31,)
# (24,)
# (93,)
# (132,)
# (59,)
# (34,)
# (40,)
# (27,)
# (44,)
# (41,)
# (173,)
# (173,)
# (140,)
# (97,)
# (137,)
# (108,)
# (84,)
# (44,)
# (53,)
# (96,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (131,)
# (173,)
# (173,)
# (173,)
# (89,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (149,)
# (155,)
# (104,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (102,)
# (62,)
# (63,)
# (27,)
# (10,)
# (13,)
# (26,)
# (53,)
# (70,)
# (169,)
# (11,)
# (26,)
# (16,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (90,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (100,)
# (173,)
# (99,)
# (115,)
# (28,)
# (52,)
# (19,)
# (24,)
# (20,)
# (75,)
# (85,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (58,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (112,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (38,)
# (50,)
# (116,)
# (47,)
# (72,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (29,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (35,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (61,)
# (43,)
# (110,)
# (116,)
# (165,)
# (61,)
# (128,)
# (55,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (57,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (19,)
# (28,)
# (9,)
# (11,)
# (10,)
# (14,)
# (19,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (78,)
# (166,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (16,)
# (56,)
# (173,)
# (151,)
# (173,)
# (113,)
# (74,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (136,)
# (173,)
# (173,)
# (173,)
# (62,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (37,)
# (87,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (45,)
# (115,)
# (67,)
# (101,)
# (131,)
# (81,)
# (98,)
# (142,)
# (92,)
# (142,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (140,)
# (128,)
# (173,)
# (80,)
# (60,)
# (57,)
# (41,)
# (52,)
# (156,)
# (46,)
# (35,)
# (54,)
# (60,)
# (38,)
# (103,)
# (65,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (14,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (49,)
# (59,)
# (40,)
# (35,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (45,)
# (67,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (71,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (34,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (33,)
# (78,)
# (42,)
# (33,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (171,)
# (103,)
# (31,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (121,)
# (173,)
# (173,)
# (65,)
# (88,)
# (104,)
# (173,)
# (173,)
# (173,)
# (54,)
# (117,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (136,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (58,)
# (129,)
# (164,)
# (95,)
# (151,)
# (102,)
# (173,)
# (173,)
# (106,)
# (103,)
# (54,)
# (127,)
# (143,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (46,)
# (173,)
# (93,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (136,)
# (173,)
# (173,)
# (173,)
# (173,)
# (29,)
# (42,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (28,)
# (25,)
# (66,)
# (78,)
# (56,)
# (79,)
# (58,)
# (84,)
# (85,)
# (85,)
# (74,)
# (90,)
# (79,)
# (73,)
# (84,)
# (89,)
# (88,)
# (114,)
# (131,)
# (120,)
# (103,)
# (109,)
# (124,)
# (123,)
# (117,)
# (104,)
# (104,)
# (105,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (102,)
# (120,)
# (152,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (33,)
# (82,)
# (78,)
# (38,)
# (54,)
# (37,)
# (47,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (90,)
# (99,)
# (127,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (118,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (24,)
# (82,)
# (20,)
# (77,)
# (78,)
# (49,)
# (42,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (84,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (58,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (94,)
# (173,)
# (173,)
# (173,)
# (173,)
# (91,)
# (173,)
# (42,)
# (45,)
# (65,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (127,)
# (173,)
# (91,)
# (75,)
# (63,)
# (27,)
# (77,)
# (36,)
# (32,)
# (32,)
# (84,)
# (144,)
# (59,)
# (44,)
# (130,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (45,)
# (124,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (41,)
# (26,)
# (30,)
# (62,)
# (84,)
# (59,)
# (54,)
# (135,)
# (36,)
# (50,)
# (50,)
# (27,)
# (173,)
# (65,)
# (71,)
# (66,)
# (66,)
# (25,)
# (32,)
# (46,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (53,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (47,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (52,)
# (100,)
# (96,)
# (92,)
# (173,)
# (173,)
# (173,)
# (173,)
# (105,)
# (138,)
# (128,)
# (172,)
# (173,)
# (41,)
# (62,)
# (173,)
# (69,)
# (55,)
# (46,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (103,)
# (173,)
# (173,)
# (29,)
# (173,)
# (173,)
# (173,)
# (64,)
# (173,)
# (173,)
# (69,)
# (159,)
# (167,)
# (173,)
# (173,)
# (173,)
# (61,)
# (89,)
# (37,)
# (40,)
# (53,)
# (173,)
# (67,)
# (93,)
# (79,)
# (58,)
# (173,)
# (58,)
# (112,)
# (75,)
# (127,)
# (36,)
# (56,)
# (100,)
# (93,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (48,)
# (31,)
# (27,)
# (27,)
# (12,)
# (14,)
# (66,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (43,)
# (136,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (12,)
# (22,)
# (13,)
# (21,)
# (90,)
# (97,)
# (173,)
# (59,)
# (59,)
# (35,)
# (22,)
# (24,)
# (26,)
# (21,)
# (58,)
# (58,)
# (73,)
# (61,)
# (74,)
# (75,)
# (103,)
# (48,)
# (11,)
# (51,)
# (65,)
# (81,)
# (45,)
# (49,)
# (112,)
# (173,)
# (173,)
# (173,)
# (173,)
# (15,)
# (16,)
# (17,)
# (11,)
# (173,)
# (31,)
# (26,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (126,)
# (114,)
# (10,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (50,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (131,)
# (130,)
# (156,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (21,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (80,)
# (63,)
# (119,)
# (96,)
# (94,)
# (90,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (44,)
# (57,)
# (173,)
# (93,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (152,)
# (45,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (15,)
# (153,)
# (173,)
# (38,)
# (136,)
# (126,)
# (146,)
# (68,)
# (31,)
# (71,)
# (115,)
# (171,)
# (173,)
# (75,)
# (173,)
# (163,)
# (101,)
# (56,)
# (86,)
# (71,)
# (99,)
# (31,)
# (120,)
# (173,)
# (173,)
# (173,)
# (12,)
# (60,)
# (74,)
# (82,)
# (151,)
# (60,)
# (62,)
# (82,)
# (113,)
# (95,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (56,)
# (62,)
# (162,)
# (28,)
# (55,)
# (41,)
# (73,)
# (38,)
# (50,)
# (23,)
# (25,)
# (33,)
# (25,)
# (28,)
# (30,)
# (37,)
# (27,)
# (67,)
# (27,)
# (22,)
# (23,)
# (46,)
# (30,)
# (21,)
# (25,)
# (81,)
# (22,)
# (22,)
# (21,)
# (98,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (61,)
# (59,)
# (67,)
# (79,)
# (62,)
# (53,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (73,)
# (173,)
# (112,)
# (173,)
# (173,)
# (173,)
# (173,)
# (169,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (41,)
# (87,)
# (93,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (121,)
# (173,)
# (173,)
# (52,)
# (44,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (33,)
# (174,)
# (174,)
# (174,)
# (174,)
# (174,)
# (174,)
# (174,)
# (34,)
# (35,)
# (130,)
# (94,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (41,)
# (61,)
# (96,)
# (70,)
# (121,)
# (25,)
# (173,)
# (64,)
# (114,)
# (173,)
# (173,)
# (158,)
# (47,)
# (69,)
# (25,)
# (42,)
# (38,)
# (69,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (121,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (74,)
# (153,)
# (148,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (11,)
# (13,)
# (16,)
# (44,)
# (173,)
# (173,)
# (173,)
# (57,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (88,)
# (71,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (43,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (8,)
# (22,)
# (27,)
# (17,)
# (56,)
# (47,)
# (80,)
# (19,)
# (8,)
# (9,)
# (11,)
# (8,)
# (173,)
# (13,)
# (12,)
# (16,)
# (19,)
# (173,)
# (139,)
# (24,)
# (138,)
# (71,)
# (45,)
# (15,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (55,)
# (63,)
# (12,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (47,)
# (50,)
# (52,)
# (62,)
# (57,)
# (65,)
# (62,)
# (65,)
# (59,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (44,)
# (19,)
# (51,)
# (37,)
# (27,)
# (10,)
# (10,)
# (15,)
# (14,)
# (12,)
# (16,)
# (40,)
# (18,)
# (40,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (63,)
# (173,)
# (173,)
# (173,)
# (31,)
# (120,)
# (57,)
# (112,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (34,)
# (24,)
# (44,)
# (58,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (103,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (39,)
# (34,)
# (157,)
# (117,)
# (173,)
# (173,)
# (173,)
# (73,)
# (161,)
# (173,)
# (173,)
# (173,)
# (173,)
# (155,)
# (173,)
# (173,)
# (173,)
# (63,)
# (20,)
# (173,)
# (47,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (19,)
# (22,)
# (18,)
# (173,)
# (173,)
# (34,)
# (38,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (50,)
# (52,)
# (56,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (169,)
# (173,)
# (173,)
# (173,)
# (173,)
# (39,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (94,)
# (74,)
# (97,)
# (53,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (117,)
# (173,)
# (22,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (63,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (110,)
# (118,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (152,)
# (173,)
# (81,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (63,)
# (88,)
# (159,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (126,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (65,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (39,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (23,)
# (16,)
# (23,)
# (22,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (69,)
# (27,)
# (61,)
# (33,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (105,)
# (170,)
# (173,)
# (173,)
# (173,)
# (70,)
# (109,)
# (173,)
# (173,)
# (173,)
# (93,)
# (156,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (19,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (93,)
# (110,)
# (97,)
# (47,)
# (173,)
# (173,)
# (173,)
# (173,)
# (63,)
# (67,)
# (69,)
# (97,)
# (59,)
# (77,)
# (61,)
# (53,)
# (51,)
# (52,)
# (58,)
# (84,)
# (131,)
# (36,)
# (137,)
# (118,)
# (95,)
# (43,)
# (53,)
# (23,)
# (62,)
# (43,)
# (57,)
# (78,)
# (151,)
# (72,)
# (95,)
# (171,)
# (35,)
# (173,)
# (112,)
# (35,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (97,)
# (100,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (20,)
# (14,)
# (173,)
# (173,)
# (173,)
# (173,)
# (60,)
# (9,)
# (41,)
# (24,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (131,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (163,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (140,)
# (171,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (171,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (141,)
# (91,)
# (134,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (139,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (50,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (171,)
# (173,)
# (173,)
# (173,)
# (173,)
# (61,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (29,)
# (45,)
# (37,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (127,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (83,)
# (173,)
# (173,)
# (87,)
# (173,)
# (54,)
# (96,)
# (95,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (169,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (25,)
# (21,)
# (16,)
# (18,)
# (18,)
# (9,)
# (8,)
# (8,)
# (27,)
# (38,)
# (28,)
# (40,)
# (45,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (58,)
# (28,)
# (26,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (165,)
# (173,)
# (173,)
# (168,)
# (157,)
# (52,)
# (144,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (145,)
# (132,)
# (173,)
# (173,)
# (160,)
# (82,)
# (149,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (109,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (43,)
# (33,)
# (34,)
# (31,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (59,)
# (81,)
# (127,)
# (52,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (116,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (58,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (107,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (23,)
# (25,)
# (13,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (46,)
# (108,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (54,)
# (63,)
# (99,)
# (89,)
# (57,)
# (66,)
# (74,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (99,)
# (173,)
# (43,)
# (173,)
# (59,)
# (173,)
# (83,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (50,)
# (53,)
# (91,)
# (28,)
# (59,)
# (49,)
# (150,)
# (173,)
# (78,)
# (7,)
# (3,)
# (3,)
# (3,)
# (3,)
# (5,)
# (131,)
# (173,)
# (173,)
# (173,)
# (173,)
# (48,)
# (84,)
# (72,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (16,)
# (89,)
# (90,)
# (82,)
# (57,)
# (70,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (56,)
# (33,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (18,)
# (99,)
# (75,)
# (36,)
# (16,)
# (27,)
# (40,)
# (57,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (63,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (96,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (48,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (90,)
# (16,)
# (17,)
# (16,)
# (136,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (66,)
# (119,)
# (173,)
# (173,)
# (173,)
# (47,)
# (142,)
# (25,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (120,)
# (137,)
# (120,)
# (122,)
# (66,)
# (72,)
# (72,)
# (50,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (110,)
# (173,)
# (43,)
# (150,)
# (123,)
# (70,)
# (96,)
# (70,)
# (96,)
# (86,)
# (64,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (59,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (128,)
# (87,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (27,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (173,)
# (93,)
# (151,)
# (109,)
# (109,)
# Finished feature extraction from  8732  files

# %%
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical

# Convert features and corresponding classification labels into numpy arrays
X = np.array(featuresdf.feature.tolist())
y = np.array(featuresdf.class_label.tolist())

# Encode the classification labels
le = LabelEncoder()
yy = to_categorical(le.fit_transform(y)) 

# split the dataset 
from sklearn.model_selection import train_test_split 

x_train, x_test, y_train, y_test = train_test_split(X, yy, test_size=0.2, random_state = 42)

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.utils import np_utils
from sklearn import metrics 

num_rows = 40
num_columns = 174
num_channels = 1

x_train = x_train.reshape(x_train.shape[0], num_rows,num_columns, num_channels)
x_test = x_test.reshape(x_test.shape[0], num_rows, num_columns, num_channels)
print(x_train.shape)
num_labels = yy.shape[1]
filter_size = 2

# Construct model 
model = Sequential()
model.add(Conv2D(filters=16, kernel_size=2, input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=32, kernel_size=2, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=2, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=128, kernel_size=2, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))
model.add(GlobalAveragePooling2D())

model.add(Dense(num_labels, activation='softmax'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-fb267857e9ad> in <module>
#      11 num_channels = 1
#      12
# ---> 13 x_train = x_train.reshape(x_train.shape[0], num_rows,num_columns, num_channels)
#      14 x_test = x_test.reshape(x_test.shape[0], num_rows, num_columns, num_channels)
#      15 print(x_train.shape)
#
# ValueError: cannot reshape array of size 6985 into shape (6985,40,174,1)

# %%
print(featuresdf["feature"].shape)
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# Display model architecture summary 
model.summary()

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# (8732,)
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_25 (Conv2D)           (None, 39, 173, 16)       80
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 19, 86, 16)        0
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 19, 86, 16)        0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 18, 85, 32)        2080
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 9, 42, 32)         0
# _________________________________________________________________
# dropout_45 (Dropout)         (None, 9, 42, 32)         0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 8, 41, 64)         8256
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 4, 20, 64)         0
# _________________________________________________________________
# dropout_46 (Dropout)         (None, 4, 20, 64)         0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 3, 19, 128)        32896
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 1, 9, 128)         0
# _________________________________________________________________
# dropout_47 (Dropout)         (None, 1, 9, 128)         0
# _________________________________________________________________
# global_average_pooling2d_6 ( (None, 128)               0
# _________________________________________________________________
# dense_36 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 44,602
# Trainable params: 44,602
# Non-trainable params: 0
# _________________________________________________________________
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-d27731ee026d> in <module>
#       7
#       8 # Calculate pre-training accuracy
# ----> 9 score = model.evaluate(x_test, y_test, verbose=1)
#      10 accuracy = 100*score[1]
#      11
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict)
#    1377             with trace.Trace('TraceContext', graph_type='test', step_num=step):
#    1378               callbacks.on_test_batch_begin(step)
# -> 1379               tmp_logs = test_function(iterator)
#    1380               if data_handler.should_sync:
#    1381                 context.async_wait()
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     821       # This is the first call of __call__, so we have to initialize.
#     822       initializers = []
# --> 823       self._initialize(args, kwds, add_initializers_to=initializers)
#     824     finally:
#     825       # At this point we know that the initialization is complete (or less
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     694     self._graph_deleter = FunctionDeleter(self._lifted_initializer_graph)
#     695     self._concrete_stateful_fn = (
# --> 696         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
#     697             *args, **kwds))
#     698
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2853       args, kwargs = None, None
#    2854     with self._lock:
# -> 2855       graph_function, _, _ = self._maybe_define_function(args, kwargs)
#    2856     return graph_function
#    2857
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3211
#    3212       self._function_cache.missed.add(call_context_key)
# -> 3213       graph_function = self._create_graph_function(args, kwargs)
#    3214       self._function_cache.primary[cache_key] = graph_function
#    3215       return graph_function, args, kwargs
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3063     arg_names = base_arg_names + missing_arg_names
#    3064     graph_function = ConcreteFunction(
# -> 3065         func_graph_module.func_graph_from_py_func(
#    3066             self._name,
#    3067             self._python_function,
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     984         _, original_func = tf_decorator.unwrap(python_func)
#     985
# --> 986       func_outputs = python_func(*func_args, **func_kwargs)
#     987
#     988       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     598         # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     599         # the function a weak reference to itself to avoid a reference cycle.
# --> 600         return weak_wrapped_fn().__wrapped__(*args, **kwds)
#     601     weak_wrapped_fn = weakref.ref(wrapped_fn)
#     602
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     971           except Exception as e:  # pylint:disable=broad-except
#     972             if hasattr(e, "ag_error_metadata"):
# --> 973               raise e.ag_error_metadata.to_exception(e)
#     974             else:
#     975               raise
#
# ValueError: in user code:
#
#     /Users/steventseng/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1224 test_function  *
#         return step_function(self, iterator)
#     /Users/steventseng/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1215 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /Users/steventseng/anaconda3/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:1211 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /Users/steventseng/anaconda3/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:2585 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /Users/steventseng/anaconda3/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:2945 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /Users/steventseng/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1208 run_step  **
#         outputs = model.test_step(data)
#     /Users/steventseng/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1174 test_step
#         y_pred = self(x, training=False)
#     /Users/steventseng/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py:975 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs,
#     /Users/steventseng/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/input_spec.py:191 assert_input_compatibility
#         raise ValueError('Input ' + str(input_index) + ' of layer ' +
#
#     ValueError: Input 0 of layer sequential_17 is incompatible with the layer: : expected min_ndim=4, found ndim=3. Full shape received: [None, 40, 1]
